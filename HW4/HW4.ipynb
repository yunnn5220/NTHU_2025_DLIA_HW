# %% [markdown]
# <div align="center">
#
# ### Lab 4
#
# # National Tsing Hua University
#
# #### Spring 2025
#
# #### 11320IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 4: Predicting Stock Price with Deep Learning
#
# </div>

# %% [markdown]
# ### Introduction
#
# In this lab, we explore the application of time-series datasets using Long Short-Term Memory (LSTM) networks, a type of recurrent neural network, to predict stock prices. Specifically, we will use historical price data from Nvidia to forecast the stock's price for the next day based on the prices of the previous N days. This approach is particularly relevant given the volatile nature of stock markets and the increasing reliance on automated trading systems.
#
# ### Objectives
#
# - To understand the fundamentals of LSTM networks and their application in time-series forecasting.
# - To develop a predictive model that can accurately forecast Nvidia's stock price for the next day using historical data.
#
# ### Dataset
#
# The dataset for this lab is from the "Huge Stock Market Dataset" available on Kaggle. This dataset includes daily prices and volumes for all US stocks and ETFs, with a specific focus on Nvidia (NVDA). The dataset features include:
#
# - **Date**: The recorded data points.
# - **Open**: The price at which the stock first traded upon the opening of an exchange on a given trading day.
# - **High**: The highest price at which the stock traded during the trading day.
# - **Low**: The lowest price at which the stock traded during the trading day.
# - **Close**: The price of the stock at closing time.
# - **Volume**: The number of shares or contracts traded in a security or an entire market during a given period.
# - **OpenInt**: The total number of outstanding derivative contracts, like options or futures. [More details here](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/discussion/121096)
#
# ### References
#
# - [Huge Stock Market Dataset](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs) for the dataset used in this lab.

# %% [markdown]
# ## A. Checking and Preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/113_DL_HW4/nvda.us.txt')
df
# Out:
#             Date      Open      High       Low     Close    Volume  OpenInt
# 0     1999-01-22    1.6238    1.8092    1.4379    1.5215  18297633        0
# 1     1999-01-25    1.6423    1.6980    1.5215    1.6793   3445279        0
# 2     1999-01-26    1.6980    1.7350    1.5311    1.5494   2320993        0
# 3     1999-01-27    1.5586    1.5957    1.4660    1.5494   1662658        0
# 4     1999-01-28    1.5494    1.5586    1.5311    1.5401   1540110        0
# ...          ...       ...       ...       ...       ...       ...      ...
# 4728  2017-11-06  207.2000  209.9800  206.7000  209.6300   9731783        0
# 4729  2017-11-07  210.5500  212.9000  210.0560  212.0000  10671815        0
# 4730  2017-11-08  211.8500  212.0000  207.2400  209.1600  13033902        0
# 4731  2017-11-09  205.2700  206.3300  200.3700  205.3200  23895006        0
# 4732  2017-11-10  213.0800  218.6700  211.6300  216.1400  31300857        0
#
# [4733 rows x 7 columns]

# %%
plot = df.plot('Date', 'High', figsize=(15, 5))

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4733 entries, 0 to 4732
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     4733 non-null   object
#  1   Open     4733 non-null   float64
#  2   High     4733 non-null   float64
#  3   Low      4733 non-null   float64
#  4   Close    4733 non-null   float64
#  5   Volume   4733 non-null   int64
#  6   OpenInt  4733 non-null   int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 259.0+ KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# OpenInt    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (4733, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  4733.000000  4733.000000  4733.000000  4733.000000  4.733000e+03
# mean     20.796242    21.157332    20.420417    20.805404  1.615287e+07
# std      30.236284    30.615622    29.792958    30.263705  1.272446e+07
# min       1.298900     1.317500     1.233900     1.261900  0.000000e+00
# 25%       7.988300     8.247900     7.756400     7.978900  8.181100e+06
# 50%      12.963000    13.238000    12.721000    12.990000  1.390271e+07
# 75%      19.141000    19.418000    18.778000    19.106000  2.051602e+07
# max     213.080000   218.670000   211.630000   216.140000  2.496659e+08
#
#        OpenInt
# count   4733.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %% [markdown]
# #### Converting the DataFrame to a NumPy Array

# %%
def create_sequences(input_data, output_data, window_size, step):
    sequences = []
    labels = []
    for i in range(0, len(input_data) - window_size, step):
        sequences.append(input_data[i:(i + window_size)])
        labels.append(output_data[i + window_size])
    return np.array(sequences), np.array(labels)

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt

# Select features
features = df[['Open', 'High', 'Low', 'Close']]
# features = df[['Open', 'High', 'Low', 'Close', 'Volume']]
# features = df[['Open', 'High', 'Low']]
# features = df[['Open', 'High', 'Close']]
# features = df[['Open', 'High', 'Close', 'Volume']]
# features = df[['Open', 'Close', 'Low']]

input_dim = 4


###
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
features = scaler.fit_transform(features)


###for non-normalize
# df['High'] = df['High'].astype(float)  # 防止 dtype 問題
# df = df.dropna()  # 去掉最後一行的 NaN 標籤
# labels = df['High'].shift(-1)  # Next day's high price as label
# features = features.iloc[:-1]
# labels = labels.dropna()

#for normalize
df['High'] = df['High'].astype(float)
df = df.dropna()
labels = df['High'].shift(-1)
features = features[:-1]
labels = labels.dropna()


window_size = 10
step = 5


X, y = create_sequences(features, labels, window_size=window_size, step=step)  #window_size=10, step=15

print(f'Shape of data X: {X.shape}')
print(f'Shape of data y: {y.shape}')

# split the hold-out tests
ind = np.linspace(0, len(X)-1, num=int(len(X)*0.1), dtype=int) # 10% hold-out
x_test = X[ind]
y_test = y[ind]
all_ind = np.arange(len(X))
remains_ind = np.delete(all_ind, ind)

X = X[remains_ind]
y = y[remains_ind]

# shuffle dataset
ind = np.random.permutation(len(X))
X = X[ind]
y = y[ind]
split_point = int(X.shape[0]*0.8)

x_train = X[:split_point]
y_train = y[:split_point]
x_val = X[split_point:]
y_val = y[split_point:]

print(f'Shape of data x_train: {x_train.shape}')
print(f'Shape of data y_train: {y_train.shape}')
print(f'Shape of data x_val: {x_val.shape}')
print(f'Shape of data y_val: {y_val.shape}')
print(f'Shape of data x_test: {x_test.shape}')
print(f'Shape of data y_test: {y_test.shape}')

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).float()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).float()

x_test = torch.from_numpy(x_test).float()
y_test = torch.from_numpy(y_test).float()

batch_size = 32

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)
test_dataset = TensorDataset(x_test, y_test)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in training and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
# Out:
# Shape of data X: (945, 10, 4)
# Shape of data y: (945,)
# Shape of data x_train: (680, 10, 4)
# Shape of data y_train: (680,)
# Shape of data x_val: (171, 10, 4)
# Shape of data y_val: (171,)
# Shape of data x_test: (94, 10, 4)
# Shape of data y_test: (94,)
# Number of samples in training and validation are 680 and 171.

# %% [markdown]
# ## B. Defining Neural Networks

# %%
import torch.nn as nn

class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# ## C. Training the Neural Network

# %%
# Check your GPU status.
# !nvidia-smi
# Out:
# Wed Apr 30 17:07:05 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   74C    P0             32W /   70W |     348MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []

epochs = 100

model = LSTMModel(input_dim=input_dim, hidden_dim=500, num_layers=2, output_dim=1).cuda()
print(model)

best_val_loss = float('inf')

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0

    for features, labels in train_loader:
        features = features.cuda()
        labels = labels.cuda()
        outputs = model(features).squeeze(-1)
        loss = criterion(outputs, labels)
        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Learning rate update
    lr_scheduler.step()

    avg_train_loss = total_loss / len(train_loader)

    # Validation
    model.eval()
    total_val_loss = 0.0

    with torch.no_grad():
        for features, labels in val_loader:
            features = features.cuda()
            labels = labels.cuda()
            outputs = model(features).squeeze(-1)
            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

    avg_val_loss = total_val_loss / len(val_loader)

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), 'best_model.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Val loss: {avg_val_loss:.4f}, Best Val loss: {best_val_loss:.4f}')

    # Store performance
    train_losses.append(avg_train_loss)
    val_losses.append(avg_val_loss)
# Out:
# LSTMModel(
#   (lstm): LSTM(4, 500, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=500, out_features=1, bias=True)
# )
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100, Train loss: 1078.3204, Val loss: 740.5096, Best Val loss: 740.5096
# Epoch 2/100, Train loss: 976.2591, Val loss: 739.4303, Best Val loss: 739.4303
# Epoch 3/100, Train loss: 904.2896, Val loss: 669.6490, Best Val loss: 669.6490
# Epoch 4/100, Train loss: 809.9120, Val loss: 586.4953, Best Val loss: 586.4953
# Epoch 5/100, Train loss: 699.8025, Val loss: 487.5281, Best Val loss: 487.5281
# Epoch 6/100, Train loss: 603.2211, Val loss: 419.8239, Best Val loss: 419.8239
# Epoch 7/100, Train loss: 500.4055, Val loss: 348.6333, Best Val loss: 348.6333
# Epoch 8/100, Train loss: 424.6672, Val loss: 300.8884, Best Val loss: 300.8884
# Epoch 9/100, Train loss: 364.6408, Val loss: 265.6144, Best Val loss: 265.6144
# Epoch 10/100, Train loss: 329.8050, Val loss: 237.8387, Best Val loss: 237.8387
# Epoch 11/100, Train loss: 305.5731, Val loss: 214.7590, Best Val loss: 214.7590
# Epoch 12/100, Train loss: 252.7580, Val loss: 178.8866, Best Val loss: 178.8866
# Epoch 13/100, Train loss: 217.0498, Val loss: 154.5305, Best Val loss: 154.5305
# Epoch 14/100, Train loss: 191.2579, Val loss: 138.3638, Best Val loss: 138.3638
# Epoch 15/100, Train loss: 172.2245, Val loss: 120.0315, Best Val loss: 120.0315
# Epoch 16/100, Train loss: 172.6689, Val loss: 110.1245, Best Val loss: 110.1245
# Epoch 17/100, Train loss: 139.1938, Val loss: 106.9329, Best Val loss: 106.9329
# Epoch 18/100, Train loss: 126.4532, Val loss: 85.3725, Best Val loss: 85.3725
# Epoch 19/100, Train loss: 114.1595, Val loss: 76.4520, Best Val loss: 76.4520
# Epoch 20/100, Train loss: 106.0791, Val loss: 69.1049, Best Val loss: 69.1049
# Epoch 21/100, Train loss: 97.7946, Val loss: 71.0680, Best Val loss: 69.1049
# Epoch 22/100, Train loss: 90.4860, Val loss: 61.9611, Best Val loss: 61.9611
# Epoch 23/100, Train loss: 83.3437, Val loss: 54.2888, Best Val loss: 54.2888
# Epoch 24/100, Train loss: 77.4059, Val loss: 51.4598, Best Val loss: 51.4598
# Epoch 25/100, Train loss: 70.7895, Val loss: 54.6222, Best Val loss: 51.4598
# Epoch 26/100, Train loss: 73.3918, Val loss: 41.5291, Best Val loss: 41.5291
# Epoch 27/100, Train loss: 60.6571, Val loss: 36.0912, Best Val loss: 36.0912
# Epoch 28/100, Train loss: 52.5194, Val loss: 32.2828, Best Val loss: 32.2828
# Epoch 29/100, Train loss: 52.4978, Val loss: 42.5967, Best Val loss: 32.2828
# Epoch 30/100, Train loss: 51.1581, Val loss: 27.4113, Best Val loss: 27.4113
# Epoch 31/100, Train loss: 42.7181, Val loss: 24.9836, Best Val loss: 24.9836
# Epoch 32/100, Train loss: 39.7840, Val loss: 23.0189, Best Val loss: 23.0189
# Epoch 33/100, Train loss: 36.1797, Val loss: 29.3013, Best Val loss: 23.0189
# Epoch 34/100, Train loss: 49.9822, Val loss: 23.9071, Best Val loss: 23.0189
# Epoch 35/100, Train loss: 33.3035, Val loss: 17.9477, Best Val loss: 17.9477
# Epoch 36/100, Train loss: 31.6353, Val loss: 18.5909, Best Val loss: 17.9477
# Epoch 37/100, Train loss: 29.8472, Val loss: 16.6894, Best Val loss: 16.6894
# Epoch 38/100, Train loss: 23.8032, Val loss: 14.1663, Best Val loss: 14.1663
# Epoch 39/100, Train loss: 25.0091, Val loss: 12.4563, Best Val loss: 12.4563
# Epoch 40/100, Train loss: 21.2641, Val loss: 11.9727, Best Val loss: 11.9727
# Epoch 41/100, Train loss: 21.3557, Val loss: 12.3300, Best Val loss: 11.9727
# Epoch 42/100, Train loss: 20.8570, Val loss: 12.7253, Best Val loss: 11.9727
# Epoch 43/100, Train loss: 19.4785, Val loss: 10.4069, Best Val loss: 10.4069
# Epoch 44/100, Train loss: 17.8131, Val loss: 9.8200, Best Val loss: 9.8200
# Epoch 45/100, Train loss: 23.4710, Val loss: 10.3956, Best Val loss: 9.8200
# Epoch 46/100, Train loss: 15.6652, Val loss: 9.1567, Best Val loss: 9.1567
# Epoch 47/100, Train loss: 14.7732, Val loss: 8.1482, Best Val loss: 8.1482
# Epoch 48/100, Train loss: 14.3867, Val loss: 7.2643, Best Val loss: 7.2643
# Epoch 49/100, Train loss: 14.0649, Val loss: 8.1925, Best Val loss: 7.2643
# Epoch 50/100, Train loss: 12.7921, Val loss: 7.1375, Best Val loss: 7.1375
# Epoch 51/100, Train loss: 22.1861, Val loss: 7.6101, Best Val loss: 7.1375
# Epoch 52/100, Train loss: 16.7919, Val loss: 6.3434, Best Val loss: 6.3434
# Epoch 53/100, Train loss: 10.9923, Val loss: 6.4236, Best Val loss: 6.3434
# Epoch 54/100, Train loss: 11.0998, Val loss: 6.6447, Best Val loss: 6.3434
# Epoch 55/100, Train loss: 10.3355, Val loss: 6.2197, Best Val loss: 6.2197
# Epoch 56/100, Train loss: 10.1321, Val loss: 6.0334, Best Val loss: 6.0334
# Epoch 57/100, Train loss: 10.1258, Val loss: 6.5277, Best Val loss: 6.0334
# Epoch 58/100, Train loss: 9.6401, Val loss: 5.3851, Best Val loss: 5.3851
# Epoch 59/100, Train loss: 12.6972, Val loss: 5.3402, Best Val loss: 5.3402
# Epoch 60/100, Train loss: 8.8974, Val loss: 5.5595, Best Val loss: 5.3402
# Epoch 61/100, Train loss: 8.7674, Val loss: 5.4727, Best Val loss: 5.3402
# Epoch 62/100, Train loss: 12.3964, Val loss: 5.8479, Best Val loss: 5.3402
# Epoch 63/100, Train loss: 8.8302, Val loss: 5.4292, Best Val loss: 5.3402
# Epoch 64/100, Train loss: 8.1905, Val loss: 4.8114, Best Val loss: 4.8114
# Epoch 65/100, Train loss: 8.0855, Val loss: 5.5397, Best Val loss: 4.8114
# Epoch 66/100, Train loss: 8.3328, Val loss: 5.8842, Best Val loss: 4.8114
# Epoch 67/100, Train loss: 8.8032, Val loss: 5.5676, Best Val loss: 4.8114
# Epoch 68/100, Train loss: 9.2122, Val loss: 4.1432, Best Val loss: 4.1432
# Epoch 69/100, Train loss: 7.8719, Val loss: 5.4556, Best Val loss: 4.1432
# Epoch 70/100, Train loss: 7.8290, Val loss: 5.0959, Best Val loss: 4.1432
# Epoch 71/100, Train loss: 7.6143, Val loss: 5.3535, Best Val loss: 4.1432
# Epoch 72/100, Train loss: 7.6403, Val loss: 5.5505, Best Val loss: 4.1432
# Epoch 73/100, Train loss: 11.2523, Val loss: 4.7776, Best Val loss: 4.1432
# Epoch 74/100, Train loss: 7.2296, Val loss: 4.0519, Best Val loss: 4.0519
# Epoch 75/100, Train loss: 7.2230, Val loss: 4.2405, Best Val loss: 4.0519
# Epoch 76/100, Train loss: 7.0915, Val loss: 3.8990, Best Val loss: 3.8990
# Epoch 77/100, Train loss: 6.9888, Val loss: 4.4176, Best Val loss: 3.8990
# Epoch 78/100, Train loss: 6.9988, Val loss: 4.4095, Best Val loss: 3.8990
# Epoch 79/100, Train loss: 6.9942, Val loss: 3.9179, Best Val loss: 3.8990
# Epoch 80/100, Train loss: 6.8356, Val loss: 4.2976, Best Val loss: 3.8990
# Epoch 81/100, Train loss: 6.8001, Val loss: 3.9233, Best Val loss: 3.8990
# Epoch 82/100, Train loss: 7.0158, Val loss: 3.8347, Best Val loss: 3.8347
# Epoch 83/100, Train loss: 6.8137, Val loss: 4.0132, Best Val loss: 3.8347
# Epoch 84/100, Train loss: 6.7425, Val loss: 4.0095, Best Val loss: 3.8347
# Epoch 85/100, Train loss: 6.6358, Val loss: 3.8699, Best Val loss: 3.8347
# Epoch 86/100, Train loss: 6.6495, Val loss: 3.7157, Best Val loss: 3.7157
# Epoch 87/100, Train loss: 6.6318, Val loss: 3.6432, Best Val loss: 3.6432
# Epoch 88/100, Train loss: 6.6532, Val loss: 3.5212, Best Val loss: 3.5212
# Epoch 89/100, Train loss: 6.5387, Val loss: 3.6085, Best Val loss: 3.5212
# Epoch 90/100, Train loss: 8.7109, Val loss: 3.6518, Best Val loss: 3.5212
# Epoch 91/100, Train loss: 6.5163, Val loss: 3.6040, Best Val loss: 3.5212
# Epoch 92/100, Train loss: 6.5082, Val loss: 3.6831, Best Val loss: 3.5212
# Epoch 93/100, Train loss: 6.4707, Val loss: 3.6498, Best Val loss: 3.5212
# Epoch 94/100, Train loss: 6.4631, Val loss: 3.6447, Best Val loss: 3.5212
# Epoch 95/100, Train loss: 6.4645, Val loss: 3.6608, Best Val loss: 3.5212
# Epoch 96/100, Train loss: 6.5081, Val loss: 3.6289, Best Val loss: 3.5212
# Epoch 97/100, Train loss: 6.5627, Val loss: 3.6073, Best Val loss: 3.5212
# Epoch 98/100, Train loss: 6.4828, Val loss: 3.6178, Best Val loss: 3.5212
# Epoch 99/100, Train loss: 14.5562, Val loss: 3.6203, Best Val loss: 3.5212
# Epoch 100/100, Train loss: 6.4472, Val loss: 3.6198, Best Val loss: 3.5212

# %% [markdown]
# #### Visualizing the model performance

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(train_losses)
plt.plot(val_losses)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %%
# Load the trained weights
model.load_state_dict(torch.load('best_model.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

pred_value = []
actual_value = []

with torch.no_grad():
    for features, labels in test_loader:
        features = features.cuda()
        outputs = model(features).squeeze(-1)
        pred_value.append(outputs.cpu())
        actual_value.append(labels)

pred_value = torch.cat(pred_value)
actual_value = torch.cat(actual_value)

# %%
plt.figure(figsize=(10, 5))
plt.plot(pred_value[:])
plt.plot(actual_value[:])
plt.xlabel('Day')
plt.ylabel('Price')
plt.legend(['Pred', 'Actual'])

plt.show()

# %%
# from sklearn.metrics import mean_squared_error

# # 轉換成 numpy 格式
# pred_np = pred_value.detach().cpu().numpy()
# true_np = actual_value.detach().cpu().numpy()

# # 計算 MSE
# mse = mean_squared_error(true_np, pred_np)
# print("features = [Open,Close,Low]")
# print(f"Test MSE: {mse:.6f} (Window Size: {window_size}, Step Size: {step})")

model.load_state_dict(torch.load('best_model.pth'))
model.eval()
test_mse = 0.0
with torch.no_grad():
    for features, labels in test_loader:
        features = features.cuda()
        labels = labels.cuda()
        outputs = model(features).squeeze(-1)
        loss = criterion(outputs, labels)
        test_mse += loss.item()


test_mse /= len(test_loader)
print("Final Test MSE:", test_mse)
# Out:
# Final Test MSE: 15.573136985301971
