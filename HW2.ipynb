# %% [markdown]
# <div align="center">
#
# ###### Lab 2
#
# # National Tsing Hua University
#
# #### Spring 2025
#
# #### 11320IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 2: Predicting Heart Disease with Deep Learning
#
# </div>

# %% [markdown]
# ### Introduction
#
# In the realm of healthcare, early detection and accurate prediction of diseases play a crucial role in patient care and management. Heart disease remains one of the leading causes of mortality worldwide, making the development of effective diagnostic tools essential. This lab leverages deep learning to predict the presence of heart disease in patients using a subset of 14 key attributes from the Cleveland Heart Disease Database. The objective is to explore and apply deep learning techniques to distinguish between the presence and absence of heart disease based on clinical parameters.
#
# Throughout this lab, you'll engage with the following key activities:
# - Use [Pandas](https://pandas.pydata.org) to process the CSV files.
# - Use [PyTorch](https://pytorch.org) to build an Artificial Neural Network (ANN) to fit the dataset.
# - Evaluate the performance of the trained model to understand its accuracy.
#
# ### Attribute Information
#
# 1. age: Age of the patient in years
# 2. sex: (Male/Female)
# 3. cp: Chest pain type (4 types: low, medium, high, and severe)
# 4. trestbps: Resting blood pressure
# 5. chol: Serum cholesterol in mg/dl
# 6. fbs: Fasting blood sugar > 120 mg/dl
# 7. restecg: Resting electrocardiographic results (values 0,1,2)
# 8. thalach: Maximum heart rate achieved
# 9. exang: Exercise induced angina
# 10. oldpeak: Oldpeak = ST depression induced by exercise relative to rest
# 11. slope: The slope of the peak exercise ST segment
# 12. ca: Number of major vessels (0-3) colored by fluoroscopy
# 13. thal: 3 = normal; 6 = fixed defect; 7 = reversible defect
# 14. target: target have disease or not (1=yes, 0=no)
#
# ### References
# - [UCI Heart Disease Data](https://www.kaggle.com/datasets/redwankarimsony/heart-disease-data) for the dataset we use in this lab.

# %% [markdown]
# ## A. Checking and Preprocessing

# %%
# hw1
# time = 9
learning_rate = 0.001
batch_size = 32
hidden_units = 256
manual_results = []

##原始
# learning_rate = 0.001
# batch_size = 32
# hidden_units = 256

# %%
import pandas as pd

df = pd.read_csv('heart_dataset_train_all.csv')
df
# Out:
#      age     sex      cp  trestbps   chol  fbs  restecg  thalach  exang  \
# 0     41    Male  medium     105.0  198.0    0      1.0    168.0      0
# 1     65  Female     low     120.0  177.0    0      1.0    140.0      0
# 2     44  Female  medium     130.0  219.0    0      0.0    188.0      0
# 3     54  Female    high     125.0  273.0    0      0.0    152.0      0
# 4     51  Female  severe     125.0  213.0    0      0.0    125.0      1
# ..   ...     ...     ...       ...    ...  ...      ...      ...    ...
# 268   40  Female     low     110.0  167.0    0      0.0    114.0      1
# 269   60  Female     low     117.0  230.0    1      1.0    160.0      1
# 270   64  Female    high     140.0  335.0    0      1.0    158.0      0
# 271   43  Female     low     120.0  177.0    0      0.0    120.0      1
# 272   57  Female     low     150.0  276.0    0      0.0    112.0      1
#
#      oldpeak  slope  ca  thal  target
# 0        0.0    2.0   1   2.0     1.0
# 1        0.4    2.0   0   3.0     1.0
# 2        0.0    2.0   0   2.0     1.0
# 3        0.5    0.0   1   2.0     1.0
# 4        1.4    2.0   1   2.0     1.0
# ..       ...    ...  ..   ...     ...
# 268      2.0    1.0   0   3.0     0.0
# 269      1.4    2.0   2   3.0     0.0
# 270      0.0    2.0   0   2.0     0.0
# 271      2.5    1.0   0   3.0     0.0
# 272      0.6    1.0   1   1.0     0.0
#
# [273 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       273 non-null    int64
#  1   sex       272 non-null    object
#  2   cp        272 non-null    object
#  3   trestbps  272 non-null    float64
#  4   chol      271 non-null    float64
#  5   fbs       273 non-null    int64
#  6   restecg   272 non-null    float64
#  7   thalach   272 non-null    float64
#  8   exang     273 non-null    int64
#  9   oldpeak   273 non-null    float64
#  10  slope     271 non-null    float64
#  11  ca        273 non-null    int64
#  12  thal      272 non-null    float64
#  13  target    272 non-null    float64
# dtypes: float64(8), int64(4), object(2)
# memory usage: 30.0+ KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# age         0
# sex         1
# cp          1
# trestbps    1
# chol        2
# fbs         0
# restecg     1
# thalach     1
# exang       0
# oldpeak     0
# slope       2
# ca          0
# thal        1
# target      1
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (270, 14)

# %%
# Mapping 'sex' descriptions to numbers
sex_description = {
    'Male': 0,
    'Female': 1,
}
df.loc[:, 'sex'] = df['sex'].map(sex_description)

# Mapping 'cp' (chest pain) descriptions to numbers
pain_description = {
    'low': 0,
    'medium': 1,
    'high': 2,
    'severe': 3
}
df.loc[:, 'cp'] = df['cp'].map(pain_description)

df
# Out:
#      age sex cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     41   0  1     105.0  198.0    0      1.0    168.0      0      0.0
# 1     65   1  0     120.0  177.0    0      1.0    140.0      0      0.4
# 2     44   1  1     130.0  219.0    0      0.0    188.0      0      0.0
# 3     54   1  2     125.0  273.0    0      0.0    152.0      0      0.5
# 4     51   1  3     125.0  213.0    0      0.0    125.0      1      1.4
# ..   ...  .. ..       ...    ...  ...      ...      ...    ...      ...
# 268   40   1  0     110.0  167.0    0      0.0    114.0      1      2.0
# 269   60   1  0     117.0  230.0    1      1.0    160.0      1      1.4
# 270   64   1  2     140.0  335.0    0      1.0    158.0      0      0.0
# 271   43   1  0     120.0  177.0    0      0.0    120.0      1      2.5
# 272   57   1  0     150.0  276.0    0      0.0    112.0      1      0.6
#
#      slope  ca  thal  target
# 0      2.0   1   2.0     1.0
# 1      2.0   0   3.0     1.0
# 2      2.0   0   2.0     1.0
# 3      0.0   1   2.0     1.0
# 4      2.0   1   2.0     1.0
# ..     ...  ..   ...     ...
# 268    1.0   0   3.0     0.0
# 269    2.0   2   3.0     0.0
# 270    2.0   0   2.0     0.0
# 271    1.0   0   3.0     0.0
# 272    1.0   1   1.0     0.0
#
# [270 rows x 14 columns]

# %%
df.describe()
# Out:
#               age    trestbps        chol         fbs     restecg     thalach  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    54.385185  131.525926  245.607407    0.151852    0.522222  149.807407
# std      9.149713   17.904675   51.529411    0.359544    0.529314   23.217253
# min     29.000000   94.000000  126.000000    0.000000    0.000000   71.000000
# 25%     47.250000  120.000000  210.250000    0.000000    0.000000  134.500000
# 50%     56.000000  130.000000  240.500000    0.000000    1.000000  152.500000
# 75%     61.000000  140.000000  274.000000    0.000000    1.000000  167.750000
# max     77.000000  200.000000  564.000000    1.000000    2.000000  202.000000
#
#             exang     oldpeak       slope          ca        thal      target
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean     0.333333    1.024074    1.400000    0.744444    2.300000    0.544444
# std      0.472280    1.188379    0.618188    1.037166    0.623874    0.498946
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000    0.000000    2.000000    0.000000
# 50%      0.000000    0.600000    1.000000    0.000000    2.000000    1.000000
# 75%      1.000000    1.600000    2.000000    1.000000    3.000000    1.000000
# max      1.000000    6.200000    2.000000    4.000000    3.000000    1.000000

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.062222 -0.103697  0.261782  0.210520  0.109847
# sex      -0.062222  1.000000 -0.040197 -0.055463 -0.166885  0.042384
# cp       -0.103697 -0.040197  1.000000  0.035563 -0.063592  0.065869
# trestbps  0.261782 -0.055463  0.035563  1.000000  0.128444  0.170606
# chol      0.210520 -0.166885 -0.063592  0.128444  1.000000  0.003430
# fbs       0.109847  0.042384  0.065869  0.170606  0.003430  1.000000
# restecg  -0.124588 -0.069599  0.008389 -0.145195 -0.162687 -0.086165
# thalach  -0.412624 -0.058626  0.300307 -0.056631 -0.023753 -0.014297
# exang     0.111263  0.124054 -0.428233  0.067116  0.063902  0.029190
# oldpeak   0.200243  0.089726 -0.183616  0.184896  0.084355  0.007943
# slope    -0.165360 -0.038771  0.135174 -0.126553 -0.031929 -0.056866
# ca        0.254462  0.140795 -0.180598  0.093545  0.068647  0.164266
# thal      0.077368  0.198493 -0.139765  0.068690  0.121280 -0.004972
# target   -0.244798 -0.283776  0.425574 -0.173239 -0.096773 -0.068845
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.124588 -0.412624  0.111263  0.200243 -0.165360  0.254462
# sex      -0.069599 -0.058626  0.124054  0.089726 -0.038771  0.140795
# cp        0.008389  0.300307 -0.428233 -0.183616  0.135174 -0.180598
# trestbps -0.145195 -0.056631  0.067116  0.184896 -0.126553  0.093545
# chol     -0.162687 -0.023753  0.063902  0.084355 -0.031929  0.068647
# fbs      -0.086165 -0.014297  0.029190  0.007943 -0.056866  0.164266
# restecg   1.000000  0.025457 -0.089225 -0.047837  0.074982 -0.053946
# thalach   0.025457  1.000000 -0.404349 -0.340564  0.370073 -0.205060
# exang    -0.089225 -0.404349  1.000000  0.294308 -0.280124  0.106250
# oldpeak  -0.047837 -0.340564  0.294308  1.000000 -0.585472  0.223375
# slope     0.074982  0.370073 -0.280124 -0.585472  1.000000 -0.083491
# ca       -0.053946 -0.205060  0.106250  0.223375 -0.083491  1.000000
# thal     -0.003377 -0.078637  0.189253  0.200315 -0.090606  0.136160
# target    0.101817  0.432687 -0.457502 -0.443504  0.363983 -0.391031
#
#               thal    target
# age       0.077368 -0.244798
# sex       0.198493 -0.283776
# cp       -0.139765  0.425574
# trestbps  0.068690 -0.173239
# chol      0.121280 -0.096773
# fbs      -0.004972 -0.068845
# restecg  -0.003377  0.101817
# thalach  -0.078637  0.432687
# exang     0.189253 -0.457502
# oldpeak   0.200315 -0.443504
# slope    -0.090606  0.363983
# ca        0.136160 -0.391031
# thal      1.000000 -0.311701
# target   -0.311701  1.000000

# %% [markdown]
# #### Converting the DataFrame to a NumPy Array

# %%
import numpy as np

np_data = df.values
np_data.shape
np_data = df.astype('float32').values###

# %%
split_point = int(np_data.shape[0]*0.7)

np.random.shuffle(np_data)

x_train = np_data[:split_point, :13]
y_train = np_data[:split_point, 13]
x_val = np_data[split_point:, :13]
y_val = np_data[split_point:, 13]

# %%
# print(np_data.dtype)

import torch
from torch.utils.data import DataLoader, TensorDataset

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).long()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).long()

# batch_size = batch_size#####

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in train and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
# Out:
# Number of samples in train and validation are 189 and 81.

# %% [markdown]
# ## B. Defining Neural Networks
#
# In PyTorch, we can use **class** to define our custom neural network architectures by subclassing the `nn.Module` class. This gives our neural network all the functionality it needs to work with PyTorch's other utilities and keeps our implementation organized.
#
# - Neural networks are defined by subclassing `nn.Module`.
# - The layers of the neural network are initialized in the `__init__` method.
# - The forward pass operations on input data are defined in the `forward` method.
#
# It's worth noting that while we only define the forward pass, PyTorch will automatically derive the backward pass for us, which is used during training to update the model's weights."

# %%
import torch.nn as nn

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(13, hidden_units),###
            nn.ReLU(),
            nn.Linear(hidden_units, hidden_units),
            nn.ReLU(),
            nn.Linear(hidden_units, 2)###
        ).cuda()

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## C. Training the Neural Network

# %%
# Check your GPU status.
# !nvidia-smi

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR, StepLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

epochs = 100

model = Model()
# print(model)

train_losses = []#
val_losses = []#
train_accuracies = []#
val_accuracies = []#


best_val_loss = float('inf')
best_val_acc = -1

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0
    train_correct = 0
    total_train_samples = 0

    for features, labels in train_loader:
        features = features.cuda()
        labels = labels.cuda()

        outputs = model(features)

        loss = criterion(outputs, labels)
        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_predicted = outputs.argmax(-1)
        train_correct += (train_predicted == labels).sum().item()
        total_train_samples += labels.size(0)

    # Learning rate update
    lr_scheduler.step()

    avg_train_loss = total_loss / len(train_loader)
    train_accuracy = 100. * train_correct / total_train_samples

    # Validation
    model.eval()
    total_val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for features, labels in val_loader:
            features = features.cuda()
            labels = labels.cuda()

            outputs = model(features)

            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

            predicted = outputs.argmax(-1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    avg_val_loss = total_val_loss / len(val_loader)
    val_accuracy = 100. * correct / total

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss

    if val_accuracy > best_val_acc:
        best_val_acc = val_accuracy
        torch.save(model.state_dict(), 'model_classification.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Train acc: {train_accuracy:.4f}%, Val loss: {avg_val_loss:.4f}, Val acc: {val_accuracy:.4f}%, Best Val loss: {best_val_loss:.4f} Best Val acc: {best_val_acc:.2f}%')

    train_losses.append(avg_train_loss)###
    train_accuracies.append(train_accuracy)###
    val_losses.append(avg_val_loss)###
    val_accuracies.append(val_accuracy)###




    # Store performance
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100, Train loss: 5.1455, Train acc: 56.0847%, Val loss: 7.4943, Val acc: 45.6790%, Best Val loss: 7.4943 Best Val acc: 45.68%
# Epoch 2/100, Train loss: 3.1338, Train acc: 57.1429%, Val loss: 2.9116, Val acc: 53.0864%, Best Val loss: 2.9116 Best Val acc: 53.09%
# Epoch 3/100, Train loss: 2.0405, Train acc: 57.6720%, Val loss: 1.6912, Val acc: 62.9630%, Best Val loss: 1.6912 Best Val acc: 62.96%
# Epoch 4/100, Train loss: 1.1710, Train acc: 62.9630%, Val loss: 0.8786, Val acc: 70.3704%, Best Val loss: 0.8786 Best Val acc: 70.37%
# Epoch 5/100, Train loss: 0.8731, Train acc: 65.6085%, Val loss: 0.7025, Val acc: 76.5432%, Best Val loss: 0.7025 Best Val acc: 76.54%
# Epoch 6/100, Train loss: 0.7857, Train acc: 62.4339%, Val loss: 0.5912, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 7/100, Train loss: 0.6798, Train acc: 65.6085%, Val loss: 0.6586, Val acc: 67.9012%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 8/100, Train loss: 0.6113, Train acc: 63.4921%, Val loss: 0.7695, Val acc: 60.4938%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 9/100, Train loss: 0.5873, Train acc: 67.7249%, Val loss: 0.6397, Val acc: 70.3704%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 10/100, Train loss: 0.5771, Train acc: 69.3122%, Val loss: 0.6182, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 11/100, Train loss: 0.5859, Train acc: 66.6667%, Val loss: 0.6274, Val acc: 72.8395%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 12/100, Train loss: 0.5473, Train acc: 70.8995%, Val loss: 0.7340, Val acc: 62.9630%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 13/100, Train loss: 0.6158, Train acc: 62.9630%, Val loss: 0.8295, Val acc: 59.2593%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 14/100, Train loss: 0.7217, Train acc: 61.9048%, Val loss: 1.0695, Val acc: 54.3210%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 15/100, Train loss: 0.7236, Train acc: 61.3757%, Val loss: 1.3077, Val acc: 49.3827%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 16/100, Train loss: 0.6466, Train acc: 68.2540%, Val loss: 0.6406, Val acc: 76.5432%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 17/100, Train loss: 0.6058, Train acc: 68.2540%, Val loss: 0.6468, Val acc: 71.6049%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 18/100, Train loss: 0.5416, Train acc: 69.8413%, Val loss: 0.6786, Val acc: 69.1358%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 19/100, Train loss: 0.5881, Train acc: 65.6085%, Val loss: 0.7523, Val acc: 65.4321%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 20/100, Train loss: 0.5461, Train acc: 70.8995%, Val loss: 0.6719, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 21/100, Train loss: 0.5080, Train acc: 73.5450%, Val loss: 0.6917, Val acc: 70.3704%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 22/100, Train loss: 0.5266, Train acc: 70.8995%, Val loss: 0.7090, Val acc: 70.3704%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 23/100, Train loss: 0.5227, Train acc: 72.4868%, Val loss: 0.6801, Val acc: 72.8395%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 24/100, Train loss: 0.4983, Train acc: 74.0741%, Val loss: 1.0606, Val acc: 51.8519%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 25/100, Train loss: 0.6297, Train acc: 67.1958%, Val loss: 1.1288, Val acc: 51.8519%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 26/100, Train loss: 0.7433, Train acc: 64.5503%, Val loss: 0.6874, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 27/100, Train loss: 0.6000, Train acc: 65.0794%, Val loss: 0.7075, Val acc: 72.8395%, Best Val loss: 0.5912 Best Val acc: 76.54%
# Epoch 28/100, Train loss: 0.5415, Train acc: 72.4868%, Val loss: 0.6903, Val acc: 77.7778%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 29/100, Train loss: 0.4886, Train acc: 74.0741%, Val loss: 0.6944, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 30/100, Train loss: 0.4906, Train acc: 74.0741%, Val loss: 0.7127, Val acc: 69.1358%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 31/100, Train loss: 0.5655, Train acc: 71.4286%, Val loss: 0.7142, Val acc: 69.1358%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 32/100, Train loss: 0.4986, Train acc: 73.5450%, Val loss: 0.7357, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 33/100, Train loss: 0.5434, Train acc: 69.8413%, Val loss: 0.7746, Val acc: 69.1358%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 34/100, Train loss: 0.5219, Train acc: 71.9577%, Val loss: 0.7612, Val acc: 67.9012%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 35/100, Train loss: 0.5023, Train acc: 72.4868%, Val loss: 0.7225, Val acc: 76.5432%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 36/100, Train loss: 0.4576, Train acc: 77.7778%, Val loss: 0.7502, Val acc: 72.8395%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 37/100, Train loss: 0.4513, Train acc: 76.7196%, Val loss: 0.7561, Val acc: 69.1358%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 38/100, Train loss: 0.4967, Train acc: 74.0741%, Val loss: 0.7320, Val acc: 72.8395%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 39/100, Train loss: 0.4471, Train acc: 80.9524%, Val loss: 0.8862, Val acc: 62.9630%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 40/100, Train loss: 0.4945, Train acc: 71.4286%, Val loss: 0.7849, Val acc: 69.1358%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 41/100, Train loss: 0.4788, Train acc: 74.6032%, Val loss: 0.8255, Val acc: 65.4321%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 42/100, Train loss: 0.4936, Train acc: 74.0741%, Val loss: 0.7271, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 43/100, Train loss: 0.4873, Train acc: 76.1905%, Val loss: 0.9323, Val acc: 61.7284%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 44/100, Train loss: 0.4913, Train acc: 73.5450%, Val loss: 0.8184, Val acc: 67.9012%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 45/100, Train loss: 0.4571, Train acc: 76.7196%, Val loss: 0.7993, Val acc: 69.1358%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 46/100, Train loss: 0.5028, Train acc: 74.6032%, Val loss: 0.7172, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 47/100, Train loss: 0.4798, Train acc: 75.6614%, Val loss: 0.9015, Val acc: 62.9630%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 48/100, Train loss: 0.5059, Train acc: 75.6614%, Val loss: 0.8887, Val acc: 62.9630%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 49/100, Train loss: 0.5289, Train acc: 70.3704%, Val loss: 0.7238, Val acc: 72.8395%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 50/100, Train loss: 0.4633, Train acc: 77.7778%, Val loss: 0.7397, Val acc: 70.3704%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 51/100, Train loss: 0.4409, Train acc: 77.7778%, Val loss: 0.7226, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 52/100, Train loss: 0.4294, Train acc: 77.2487%, Val loss: 0.9203, Val acc: 61.7284%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 53/100, Train loss: 0.5199, Train acc: 71.9577%, Val loss: 0.7844, Val acc: 67.9012%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 54/100, Train loss: 0.4852, Train acc: 71.4286%, Val loss: 0.7311, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 55/100, Train loss: 0.4697, Train acc: 76.1905%, Val loss: 0.7786, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 56/100, Train loss: 0.4511, Train acc: 74.6032%, Val loss: 0.8898, Val acc: 64.1975%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 57/100, Train loss: 0.4980, Train acc: 71.4286%, Val loss: 0.7369, Val acc: 71.6049%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 58/100, Train loss: 0.4267, Train acc: 78.3069%, Val loss: 0.7269, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 59/100, Train loss: 0.4367, Train acc: 79.3651%, Val loss: 0.8163, Val acc: 70.3704%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 60/100, Train loss: 0.4159, Train acc: 82.5397%, Val loss: 0.7272, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 61/100, Train loss: 0.4169, Train acc: 80.9524%, Val loss: 0.7342, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 62/100, Train loss: 0.4067, Train acc: 83.0688%, Val loss: 0.7344, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 63/100, Train loss: 0.3946, Train acc: 80.9524%, Val loss: 0.7752, Val acc: 72.8395%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 64/100, Train loss: 0.4058, Train acc: 82.5397%, Val loss: 0.7368, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 65/100, Train loss: 0.3982, Train acc: 84.1270%, Val loss: 0.7677, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 66/100, Train loss: 0.3921, Train acc: 85.1852%, Val loss: 0.7328, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 67/100, Train loss: 0.3891, Train acc: 84.1270%, Val loss: 0.7706, Val acc: 72.8395%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 68/100, Train loss: 0.4031, Train acc: 80.4233%, Val loss: 0.7379, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 69/100, Train loss: 0.3963, Train acc: 81.4815%, Val loss: 0.7420, Val acc: 72.8395%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 70/100, Train loss: 0.4041, Train acc: 80.9524%, Val loss: 0.7435, Val acc: 72.8395%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 71/100, Train loss: 0.3949, Train acc: 80.9524%, Val loss: 0.7572, Val acc: 72.8395%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 72/100, Train loss: 0.3754, Train acc: 86.7725%, Val loss: 0.7357, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 73/100, Train loss: 0.3880, Train acc: 84.6561%, Val loss: 0.7499, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 74/100, Train loss: 0.3866, Train acc: 84.1270%, Val loss: 0.7495, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 75/100, Train loss: 0.3931, Train acc: 83.0688%, Val loss: 0.7411, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 76/100, Train loss: 0.3842, Train acc: 84.1270%, Val loss: 0.7739, Val acc: 72.8395%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 77/100, Train loss: 0.3836, Train acc: 85.1852%, Val loss: 0.7403, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 78/100, Train loss: 0.3803, Train acc: 86.2434%, Val loss: 0.7513, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 79/100, Train loss: 0.3780, Train acc: 86.2434%, Val loss: 0.7496, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 80/100, Train loss: 0.3985, Train acc: 80.4233%, Val loss: 0.7423, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 81/100, Train loss: 0.3711, Train acc: 85.1852%, Val loss: 0.7784, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 82/100, Train loss: 0.3844, Train acc: 82.0106%, Val loss: 0.7468, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 83/100, Train loss: 0.3856, Train acc: 84.1270%, Val loss: 0.7409, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 84/100, Train loss: 0.3758, Train acc: 85.7143%, Val loss: 0.7631, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 85/100, Train loss: 0.3764, Train acc: 85.7143%, Val loss: 0.7528, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 86/100, Train loss: 0.3754, Train acc: 85.1852%, Val loss: 0.7466, Val acc: 76.5432%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 87/100, Train loss: 0.3759, Train acc: 85.7143%, Val loss: 0.7464, Val acc: 76.5432%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 88/100, Train loss: 0.3731, Train acc: 85.7143%, Val loss: 0.7543, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 89/100, Train loss: 0.3780, Train acc: 86.7725%, Val loss: 0.7489, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 90/100, Train loss: 0.3743, Train acc: 86.2434%, Val loss: 0.7473, Val acc: 76.5432%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 91/100, Train loss: 0.3726, Train acc: 86.2434%, Val loss: 0.7511, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 92/100, Train loss: 0.3723, Train acc: 86.2434%, Val loss: 0.7510, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 93/100, Train loss: 0.3716, Train acc: 86.2434%, Val loss: 0.7504, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 94/100, Train loss: 0.3738, Train acc: 85.1852%, Val loss: 0.7502, Val acc: 74.0741%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 95/100, Train loss: 0.3717, Train acc: 85.7143%, Val loss: 0.7485, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 96/100, Train loss: 0.3726, Train acc: 86.2434%, Val loss: 0.7481, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 97/100, Train loss: 0.3735, Train acc: 86.2434%, Val loss: 0.7482, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 98/100, Train loss: 0.3721, Train acc: 86.2434%, Val loss: 0.7484, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 99/100, Train loss: 0.3718, Train acc: 86.2434%, Val loss: 0.7486, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%
# Epoch 100/100, Train loss: 0.3717, Train acc: 86.2434%, Val loss: 0.7486, Val acc: 75.3086%, Best Val loss: 0.5912 Best Val acc: 77.78%

# %%
import pandas as pd#

results_df = pd.DataFrame({
    "Epoch": list(range(1, len(train_losses)+1)),
    "Train Loss": train_losses,
    "Train Acc": train_accuracies,
    "Val Loss": val_losses,
    "Val Acc": val_accuracies
})

results_df.tail(10)  # 顯示最後10輪#
# Out:
#      Epoch  Train Loss  Train Acc  Val Loss    Val Acc
# 190    191    0.372609  86.243386  0.748097  75.308642
# 191    192    0.372609  86.243386  0.748097  75.308642
# 192    193    0.373477  86.243386  0.748206  75.308642
# 193    194    0.373477  86.243386  0.748206  75.308642
# 194    195    0.372127  86.243386  0.748418  75.308642
# 195    196    0.372127  86.243386  0.748418  75.308642
# 196    197    0.371788  86.243386  0.748564  75.308642
# 197    198    0.371788  86.243386  0.748564  75.308642
# 198    199    0.371711  86.243386  0.748600  75.308642
# 199    200    0.371711  86.243386  0.748600  75.308642

# %% [markdown]
# #### Visualizing the model performance

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# Plotting training and validation accuracy
ax[0].plot(train_accuracies)
ax[0].plot(val_accuracies)
ax[0].set_title('Model Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['Train', 'Val'])

# Plotting training and validation loss
ax[1].plot(train_losses)
ax[1].plot(val_losses)
ax[1].set_title('Model Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %%
# read test file
test_data = pd.read_csv('heart_dataset_test.csv')
test_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   50    0   2       120   219    0        1      158      0      1.6      1
# 1   58    0   2       120   340    0        1      172      0      0.0      2
# 2   66    0   3       150   226    0        1      114      0      2.6      0
# 3   43    1   0       150   247    0        1      171      0      1.5      2
# 4   69    0   3       140   239    0        1      151      0      1.8      2
#
#    ca  thal  target
# 0   0     2       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   2     2       1

# %%
test_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
test_data = test_data.values
test_data.shape
# Out:
# (31, 14)

# %%
# Convert to PyTorch tensors
x_test = torch.from_numpy(test_data[:, :13]).float()
y_test = torch.from_numpy(test_data[:, 13]).long()

# Create datasets
test_dataset = TensorDataset(x_test, y_test)

# Create dataloaders
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
# Load the trained weights
model.load_state_dict(torch.load('model_classification.pth'))

# Set the model to evaluation mode
model.eval()

test_loss = 0.0###
test_correct = 0
test_total = 0

with torch.no_grad():
    for features, labels in test_loader:

        features = features.cuda()
        labels = labels.cuda()

        outputs = model(features)

        loss = criterion(outputs, labels)###
        test_loss += loss.item()###

        predicted = outputs.argmax(-1)
        test_correct += (predicted == labels).sum().item()
        test_total += labels.size(0)

avg_test_loss = test_loss / len(test_loader)###
test_accuracy = 100. * test_correct / test_total###


# print(f'Test accuracy is {100. * test_correct / test_total}%')
print(f'Test accuracy is {test_accuracy:.2f}%')
print(f'Test loss is {avg_test_loss:.4f}')
# Out:
# Test accuracy is 74.19%
# Test loss is 0.8119
# C:\Users\tubew\AppData\Local\Temp\ipykernel_9212\2632680942.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('model_classification.pth'))

# %%
manual_results.append({
    "LR": learning_rate,
    "Batch Size": batch_size,
    "Hidden Units": hidden_units,
    "Train Acc": f"{round(train_accuracies[-1], 2)}%",
    "Val Acc": f"{round(val_accuracies[-1], 2)}%",
    "Test Acc": f"{round(test_accuracy, 2)}%",
    "Train Loss": round(train_losses[-1], 4),
    "Val Loss": round(val_losses[-1], 4),
    "Test Loss": round(avg_test_loss, 4)
})

import pandas as pd

df_manual = pd.DataFrame(manual_results)
df_manual

# df_manual.to_csv(f"manual_results{time}.csv", index=False)
# Out:
#       LR  Batch Size  Hidden Units Train Acc Val Acc Test Acc  Train Loss  \
# 0  0.001          32           256    86.24%  75.31%   74.19%      0.3717
#
#    Val Loss  Test Loss
# 0    0.7486     0.8119

# %%
print("=== Manual Run Summary ===")
print(f"Learning rate : {learning_rate}")
print(f"Batch size    : {batch_size}")
print(f"Hidden units  : {hidden_units}")
print(f"Final Train Accuracy: {train_accuracies[-1]:.2f}%")
print(f"Final Val Accuracy  : {val_accuracies[-1]:.2f}%")
print(f"Final Train Loss    : {train_losses[-1]:.4f}")
print(f"Final Val Loss      : {val_losses[-1]:.4f}")#
print(f'Test accuracy is {test_accuracy:.2f}%')
print(f'Test loss is {avg_test_loss:.4f}')#
# Out:
# === Manual Run Summary ===
# Learning rate : 0.001
# Batch size    : 32
# Hidden units  : 256
# Final Train Accuracy: 86.24%
# Final Val Accuracy  : 75.31%
# Final Train Loss    : 0.3717
# Final Val Loss      : 0.7486
# Test accuracy is 74.19%
# Test loss is 0.8119

# %%
if 'History_list' not in globals():
    History_list = []
model = Model()

hidden_units_info = hidden_units
batch_size_info = batch_size
train_acc = train_accuracy
train_loss = avg_train_loss
val_acc = val_accuracy
val_loss = avg_val_loss
test_acc = 100. * test_correct / test_total
test_loss = avg_test_loss

History_list.append([ hidden_units_info, batch_size_info,
train_acc, train_loss, val_acc, val_loss, test_acc, test_loss ])

# %%
name_of_values = ['hidden_units' , 'batch_size' , 'Train acc' , 'Train loss' , 'Val acc' , 'Val loss' , 'Test acc', 'Test loss']
column_width = 35  # 每欄寬度
cols_per_row = 3   # 幾欄一列

# 計算總共要幾行
num_rows = (len(History_list) + cols_per_row - 1) // cols_per_row

for row in range(num_rows):
    print("=" * column_width * cols_per_row)
    
    # 印每一列的標題 (Run 1, Run 2, ...)
    for col in range(cols_per_row):
        idx = row * cols_per_row + col
        if idx < len(History_list):
            print(f"{'Run ' + str(idx + 1):<{column_width}}", end="")
    print()

    # 針對每個指標 (activation, acc, loss...) 印每一列的值
    for i in range(len(name_of_values)):
        for col in range(cols_per_row):
            idx = row * cols_per_row + col
            if idx < len(History_list):
                value = History_list[idx][i]
                print(f"{name_of_values[i] + ': ' + str(value):<{column_width}}", end="")
        print()

print("=" * column_width * cols_per_row)
# Out:
# =========================================================================================================
# Run 1                              Run 2                              Run 3
# hidden_units: 64                   hidden_units: 64                   hidden_units: 64
# batch_size: 8                      batch_size: 16                     batch_size: 32
# Train acc: 87.3015873015873        Train acc: 84.12698412698413       Train acc: 78.3068783068783
# Train loss: 0.3411140826841195     Train loss: 0.38316315909226734    Train loss: 0.4465183566013972
# Val acc: 75.30864197530865         Val acc: 83.95061728395062         Val acc: 81.48148148148148
# Val loss: 0.4690342328765176       Val loss: 0.361957219739755        Val loss: 0.46385687589645386
# Test acc: 74.19354838709677        Test acc: 77.41935483870968        Test acc: 70.96774193548387
# Test loss: 0.44936834546106474     Test loss: 0.4890295818688408      Test loss: 0.614945100079621
# =========================================================================================================
# Run 4                              Run 5                              Run 6
# hidden_units: 128                  hidden_units: 128                  hidden_units: 128
# batch_size: 8                      batch_size: 16                     batch_size: 32
# Train acc: 83.06878306878306       Train acc: 88.35978835978835       Train acc: 85.18518518518519
# Train loss: 0.38317515949408215    Train loss: 0.2956068788965543     Train loss: 0.3534908692042033
# Val acc: 88.88888888888889         Val acc: 74.07407407407408         Val acc: 77.77777777777777
# Val loss: 0.348609249022874        Val loss: 0.5435328781604767       Val loss: 0.4847014347712199
# Test acc: 74.19354838709677        Test acc: 80.64516129032258        Test acc: 77.41935483870968
# Test loss: 0.518633735155867       Test loss: 0.5349158748323398      Test loss: 0.5709030920219037
# =========================================================================================================
# Run 7                              Run 8                              Run 9
# hidden_units: 256                  hidden_units: 256                  hidden_units: 256
# batch_size: 8                      batch_size: 16                     batch_size: 32
# Train acc: 88.88888888888889       Train acc: 85.18518518518519       Train acc: 86.24338624338624
# Train loss: 0.2895993047083418     Train loss: 0.32346918682257336    Train loss: 0.3717113087574641
# Val acc: 76.54320987654322         Val acc: 82.71604938271605         Val acc: 75.30864197530865
# Val loss: 0.48172727159478446      Val loss: 0.4419800415635109       Val loss: 0.7485995789368948
# Test acc: 83.87096774193549        Test acc: 80.64516129032258        Test acc: 74.19354838709677
# Test loss: 0.40295900266257023     Test loss: 0.5355028415459299      Test loss: 0.8119340686788482
# =========================================================================================================

# %%
# History_list.clear()
